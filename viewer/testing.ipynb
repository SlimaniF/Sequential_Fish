# %%
import pandas as pd
# path = '/media/floricslimani/SSD4To/SSD_floricslimani/Fish_seq/Davide/2024-08-12 - SeqFISH - HeLa - Puro - R2TP1-2_Run7/'
path = '//media/SSD_floricslimani/Fish_seq/Davide/2025-04-24 - HeLa R2TP_Run12'

# %%
Acquisition = pd.read_feather(path+ "/result_tables/Acquisition.feather")
Spots = pd.read_feather(path+ "/result_tables/Spots.feather")
Detection = pd.read_feather(path+ "/result_tables/Detection.feather")
Drift = pd.read_feather(path+ "/result_tables/Drift.feather")
Clusters = pd.read_feather(path+ "/result_tables/Clusters.feather")
Gene_map = pd.read_feather(path+ "/result_tables/Gene_map.feather")
Detection
# Out:
#     detection_id  acquisition_id visual_name  \
# 0              1               0        None
# 1              2               1        None
# 2              3               2        None
# 3              4               3        None
# 4              5               4        None
# 5              6               5        None
# 6              7               6        None
# 7              8               7        None
# 8              9               8        None
# 9             10               9        None
# 10            11              10        None
# 11            12              11        None
# 12            13              12        None
# 13            14              13        None
# 14            15              14        None
# 15            16              15        None
# 16            17              16        None
# 17            18              17        None
# 18            19              18        None
# 19            20              19        None
# 20            21              20        None
# 21            22               0        None
# 22            23               1        None
# 23            24               2        None
# 24            25               3        None
# 25            26               4        None
# 26            27               5        None
# 27            28               6        None
# 28            29               7        None
# 29            30               8        None
# 30            31               9        None
# 31            32              10        None
# 32            33              11        None
# 33            34              12        None
# 34            35              13        None
# 35            36              14        None
# 36            37              15        None
# 37            38              16        None
# 38            39              17        None
# 39            40              18        None
# 40            41              19        None
# 41            42              20        None
#
#                                              filename     voxel_size  \
# 0   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 1   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 2   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 3   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 4   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 5   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 6   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 7   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 8   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 9   /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 10  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 11  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 12  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 13  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 14  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 15  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 16  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 17  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 18  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 19  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 20                                               None  [200, 97, 97]
# 21  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 22  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 23  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 24  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 25  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 26  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 27  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 28  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 29  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 30  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 31  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 32  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 33  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 34  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 35  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 36  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 37  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 38  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 39  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 40  /media/SSD_floricslimani/Fish_seq/Davide/2025-...  [200, 97, 97]
# 41                                               None  [200, 97, 97]
#
#           spot_size  alpha  beta  gamma  artifact_radius  cluster_size  \
# 0   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 1   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 2   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 3   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 4   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 5   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 6   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 7   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 8   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 9   [300, 140, 140]    0.5   1.0    2.0             1400           400
# 10  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 11  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 12  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 13  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 14  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 15  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 16  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 17  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 18  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 19  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 20  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 21  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 22  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 23  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 24  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 25  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 26  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 27  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 28  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 29  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 30  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 31  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 32  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 33  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 34  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 35  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 36  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 37  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 38  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 39  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 40  [300, 140, 140]    0.5   1.0    2.0             1400           400
# 41  [300, 140, 140]    0.5   1.0    2.0             1400           400
#
#     min_spot_per_cluster  Threshold_0  Threshold_1  threshold color_id  \
# 0                      5          900          900        900        0
# 1                      5         1200          300       1200        0
# 2                      5         1200          300       1200        0
# 3                      5          330          300        330        0
# 4                      5          330          300        330        0
# 5                      5          331          301        331        0
# 6                      5          332          302        332        0
# 7                      5          333          303        333        0
# 8                      5          334          304        334        0
# 9                      5          335          305        335        0
# 10                     5          336          306        336        0
# 11                     5          337          307        337        0
# 12                     5          338          308        338        0
# 13                     5          339          309        339        0
# 14                     5          340          310        340        0
# 15                     5          341          311        341        0
# 16                     5          342          312        342        0
# 17                     5          343          313        343        0
# 18                     5          344          314        344        0
# 19                     5          344          315        344        0
# 20                     5          344          315        344        0
# 21                     5          900          900        900        1
# 22                     5         1200          300        300        1
# 23                     5         1200          300        300        1
# 24                     5          330          300        300        1
# 25                     5          330          300        300        1
# 26                     5          331          301        301        1
# 27                     5          332          302        302        1
# 28                     5          333          303        303        1
# 29                     5          334          304        304        1
# 30                     5          335          305        305        1
# 31                     5          336          306        306        1
# 32                     5          337          307        307        1
# 33                     5          338          308        308        1
# 34                     5          339          309        309        1
# 35                     5          340          310        310        1
# 36                     5          341          311        311        1
# 37                     5          342          312        312        1
# 38                     5          343          313        313        1
# 39                     5          344          314        314        1
# 40                     5          344          315        315        1
# 41                     5          344          315        315        1
#
#                                            image_path image_key
# 0   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         1
# 1   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         2
# 2   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         3
# 3   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         4
# 4   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         5
# 5   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         6
# 6   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         7
# 7   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         8
# 8   /media/SSD_floricslimani/Fish_seq/Davide/2025-...         9
# 9   /media/SSD_floricslimani/Fish_seq/Davide/2025-...        10
# 10  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        11
# 11  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        12
# 12  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        13
# 13  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        14
# 14  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        15
# 15  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        16
# 16  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        17
# 17  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        18
# 18  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        19
# 19  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        20
# 20  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        21
# 21  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        22
# 22  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        23
# 23  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        24
# 24  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        25
# 25  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        26
# 26  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        27
# 27  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        28
# 28  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        29
# 29  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        30
# 30  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        31
# 31  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        32
# 32  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        33
# 33  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        34
# 34  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        35
# 35  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        36
# 36  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        37
# 37  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        38
# 38  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        39
# 39  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        40
# 40  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        41
# 41  /media/SSD_floricslimani/Fish_seq/Davide/2025-...        42

# %%
from pbwrap.utils import open_image
from utils import open_image as test
import os
import time as t

print(os.listdir(path + "/FISH_Z-stacks/Location-01"))
# Out:
# ['img011_000_000000_0000000000.ome.tif', 'img001_000_000000_0000000000.ome.tif', 'img008_000_000000_0000000000.ome.tif', 'img016_000_000000_0000000000.ome.tif', 'img015_000_000000_0000000000.ome.tif', 'img000_000_000000_0000000000.ome.tif', 'img005_000_000000_0000000000.ome.tif', 'img013_000_000000_0000000000.ome.tif', 'img019_000_000000_0000000000.ome.tif', 'img010_000_000000_0000000000.ome.tif', 'img018_000_000000_0000000000.ome.tif', 'img012_000_000000_0000000000.ome.tif', 'img007_000_000000_0000000000.ome.tif', 'img009_000_000000_0000000000.ome.tif', 'img017_000_000000_0000000000.ome.tif', 'img014_000_000000_0000000000.ome.tif', 'img004_000_000000_0000000000.ome.tif', 'img002_000_000000_0000000000.ome.tif', 'img006_000_000000_0000000000.ome.tif', 'img003_000_000000_0000000000.ome.tif']

# %%
time = t.time()
image = test(path + "/FISH_Z-stacks/Location-01/img001_000_000000_0000000000.ome.tif")
print("time to load : ",t.time() - time)
print(image.shape)
time = t.time()
image = open_image(path + "/FISH_Z-stacks/Location-01/img001_000_000000_0000000000.ome.tif")
print("time to load : ",t.time() - time)
print(image.shape)
# Out:
# time to load :  0.020459651947021484
# (1, 2004, 2004)
# time to load :  1.6833984851837158
# (102, 2004, 2004)
